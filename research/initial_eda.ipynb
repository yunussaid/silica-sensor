# %% [markdown]
# # Inital EDA (Quality Prediction in a Mining Process)
#
# This notebook covers the initial EDA for the Quality Prediction in a Mining Process dataset that can be found at:
#     https://www.kaggle.com/datasets/edumagalhaes/quality-prediction-in-a-mining-process

# %%
# !pip install -r ../requirements.txt

import os
import zipfile
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: pandas in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: seaborn in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: numpy in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 6)) (2.4.6)
# Requirement already satisfied: plotly in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 25)) (6.8.0)
# Requirement already satisfied: streamlit in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 26)) (1.58.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from pandas->-r ../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from seaborn->-r ../requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from plotly->-r ../requirements.txt (line 25)) (2.22.1)
# Requirement already satisfied: packaging in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from plotly->-r ../requirements.txt (line 25)) (26.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (6.2.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (3.1.50)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (7.35.1)
# Requirement already satisfied: pyarrow>=7.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (4.14.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from streamlit->-r ../requirements.txt (line 26)) (6.0.0)
# Requirement already satisfied: jinja2 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (4.26.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 26)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 26)) (5.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit->-r ../requirements.txt (line 26)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit->-r ../requirements.txt (line 26)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit->-r ../requirements.txt (line 26)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from requests<3,>=2.27->streamlit->-r ../requirements.txt (line 26)) (2026.6.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->-r ../requirements.txt (line 26)) (2026.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /home/yunus/Projects/ENG-M-680-Final-Project/.venv/lib/python3.14/site-packages (from uvicorn>=0.30.0->streamlit->-r ../requirements.txt (line 26)) (0.16.0)

# %% [markdown]
# ## 1. Loading Dataset, Datetime Conversion and Indexing

# %%
# Unzip dataset only if needed
if not os.path.exists("../datasets/quality_prediction_in_a_mining_process.csv"):
    with zipfile.ZipFile("../datasets/quality_prediction_in_a_mining_process.zip", 'r') as zip_ref:
        zip_ref.extractall("../datasets")

# Load dataset
df_mining = pd.read_csv("../datasets/quality_prediction_in_a_mining_process.csv", decimal=',')

# Datetime Conversion and Indexing
df_mining['date'] = pd.to_datetime(df_mining['date'])
df_mining = df_mining.set_index('date')

# Display Dataset Head
print('df_mining ', df_mining.shape, ':', sep='')
with pd.option_context('display.max_columns', None):
    display(df_mining.head())
# Out:
# df_mining (737453, 23):
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:00:00        395.713      10.0664              1.74
# 2017-03-10 01:00:00        397.383      10.0672              1.74
# 2017-03-10 01:00:00        399.668      10.0680              1.74
# 2017-03-10 01:00:00        397.939      10.0689              1.74
# 2017-03-10 01:00:00        400.254      10.0697              1.74
#
#                      Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:00:00                       249.214
# 2017-03-10 01:00:00                       249.719
# 2017-03-10 01:00:00                       249.741
# 2017-03-10 01:00:00                       249.917
# 2017-03-10 01:00:00                       250.203
#
#                      Flotation Column 02 Air Flow  \
# date
# 2017-03-10 01:00:00                       253.235
# 2017-03-10 01:00:00                       250.532
# 2017-03-10 01:00:00                       247.874
# 2017-03-10 01:00:00                       254.487
# 2017-03-10 01:00:00                       252.136
#
#                      Flotation Column 03 Air Flow  \
# date
# 2017-03-10 01:00:00                       250.576
# 2017-03-10 01:00:00                       250.862
# 2017-03-10 01:00:00                       250.313
# 2017-03-10 01:00:00                       250.049
# 2017-03-10 01:00:00                       249.895
#
#                      Flotation Column 04 Air Flow  \
# date
# 2017-03-10 01:00:00                       295.096
# 2017-03-10 01:00:00                       295.096
# 2017-03-10 01:00:00                       295.096
# 2017-03-10 01:00:00                       295.096
# 2017-03-10 01:00:00                       295.096
#
#                      Flotation Column 05 Air Flow  \
# date
# 2017-03-10 01:00:00                         306.4
# 2017-03-10 01:00:00                         306.4
# 2017-03-10 01:00:00                         306.4
# 2017-03-10 01:00:00                         306.4
# 2017-03-10 01:00:00                         306.4
#
#                      Flotation Column 06 Air Flow  \
# date
# 2017-03-10 01:00:00                       250.225
# 2017-03-10 01:00:00                       250.137
# 2017-03-10 01:00:00                       251.345
# 2017-03-10 01:00:00                       250.422
# 2017-03-10 01:00:00                       249.983
#
#                      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# date
# 2017-03-10 01:00:00                       250.884                    457.396
# 2017-03-10 01:00:00                       248.994                    451.891
# 2017-03-10 01:00:00                       248.071                    451.240
# 2017-03-10 01:00:00                       251.147                    452.441
# 2017-03-10 01:00:00                       248.928                    452.441
#
#                      Flotation Column 02 Level  Flotation Column 03 Level  \
# date
# 2017-03-10 01:00:00                    432.962                    424.954
# 2017-03-10 01:00:00                    429.560                    432.939
# 2017-03-10 01:00:00                    468.927                    434.610
# 2017-03-10 01:00:00                    458.165                    442.865
# 2017-03-10 01:00:00                    452.900                    450.523
#
#                      Flotation Column 04 Level  Flotation Column 05 Level  \
# date
# 2017-03-10 01:00:00                    443.558                    502.255
# 2017-03-10 01:00:00                    448.086                    496.363
# 2017-03-10 01:00:00                    449.688                    484.411
# 2017-03-10 01:00:00                    446.210                    471.411
# 2017-03-10 01:00:00                    453.670                    462.598
#
#                      Flotation Column 06 Level  Flotation Column 07 Level  \
# date
# 2017-03-10 01:00:00                    446.370                    523.344
# 2017-03-10 01:00:00                    445.922                    498.075
# 2017-03-10 01:00:00                    447.826                    458.567
# 2017-03-10 01:00:00                    437.690                    427.669
# 2017-03-10 01:00:00                    443.682                    425.679
#
#                      % Iron Concentrate  % Silica Concentrate
# date
# 2017-03-10 01:00:00               66.91                  1.31
# 2017-03-10 01:00:00               66.91                  1.31
# 2017-03-10 01:00:00               66.91                  1.31
# 2017-03-10 01:00:00               66.91                  1.31
# 2017-03-10 01:00:00               66.91                  1.31

# %% [markdown]
# ## 2. Dataset Summary and Descriptive Statistics

# %%
print("========= Dataset Summary =========")
print(df_mining.info())
# Out:
# ========= Dataset Summary =========
# <class 'pandas.DataFrame'>
# DatetimeIndex: 737453 entries, 2017-03-10 01:00:00 to 2017-09-09 23:00:00
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   % Iron Feed                   737453 non-null  float64
#  1   % Silica Feed                 737453 non-null  float64
#  2   Starch Flow                   737453 non-null  float64
#  3   Amina Flow                    737453 non-null  float64
#  4   Ore Pulp Flow                 737453 non-null  float64
#  5   Ore Pulp pH                   737453 non-null  float64
#  6   Ore Pulp Density              737453 non-null  float64
#  7   Flotation Column 01 Air Flow  737453 non-null  float64
#  8   Flotation Column 02 Air Flow  737453 non-null  float64
#  9   Flotation Column 03 Air Flow  737453 non-null  float64
#  10  Flotation Column 04 Air Flow  737453 non-null  float64
#  11  Flotation Column 05 Air Flow  737453 non-null  float64
#  12  Flotation Column 06 Air Flow  737453 non-null  float64
#  13  Flotation Column 07 Air Flow  737453 non-null  float64
#  14  Flotation Column 01 Level     737453 non-null  float64
#  15  Flotation Column 02 Level     737453 non-null  float64
#  16  Flotation Column 03 Level     737453 non-null  float64
#  17  Flotation Column 04 Level     737453 non-null  float64
#  18  Flotation Column 05 Level     737453 non-null  float64
#  19  Flotation Column 06 Level     737453 non-null  float64
#  20  Flotation Column 07 Level     737453 non-null  float64
#  21  % Iron Concentrate            737453 non-null  float64
#  22  % Silica Concentrate          737453 non-null  float64
# dtypes: float64(23)
# memory usage: 135.0 MB
# None

# %%
print("====== Descriptive Statistics ======")
with pd.option_context('display.max_columns', None):
    display(df_mining.describe())
# Out:
# ====== Descriptive Statistics ======
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  737453.000000  737453.000000  737453.000000  737453.000000
# mean       56.294739      14.651716    2869.140569     488.144697
# std         5.157744       6.807439    1215.203734      91.230534
# min        42.740000       1.310000       0.002026     241.669000
# 25%        52.670000       8.940000    2076.320000     431.796000
# 50%        56.080000      13.850000    3018.430000     504.393000
# 75%        59.720000      19.600000    3727.730000     553.257000
# max        65.780000      33.400000    6300.230000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  737453.000000  737453.000000     737453.000000
# mean      397.578372       9.767639          1.680380
# std         9.699785       0.387007          0.069249
# min       376.249000       8.753340          1.519820
# 25%       394.264000       9.527360          1.647310
# 50%       399.249000       9.798100          1.697600
# 75%       402.968000      10.038000          1.728330
# max       418.641000      10.808100          1.853250
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 737453.000000                 737453.000000
# mean                     280.151856                    277.159965
# std                       29.621288                     30.149357
# min                      175.510000                    175.156000
# 25%                      250.281000                    250.457000
# 50%                      299.344000                    296.223000
# 75%                      300.149000                    300.690000
# max                      373.871000                    375.992000
#
#        Flotation Column 03 Air Flow  Flotation Column 04 Air Flow  \
# count                 737453.000000                 737453.000000
# mean                     281.082397                    299.447794
# std                       28.558268                      2.572538
# min                      176.469000                    292.195000
# 25%                      250.855000                    298.262566
# 50%                      298.696000                    299.805000
# 75%                      300.382000                    300.638000
# max                      364.346000                    305.871000
#
#        Flotation Column 05 Air Flow  Flotation Column 06 Air Flow  \
# count                 737453.000000                 737453.000000
# mean                     299.917814                    292.071485
# std                        3.636579                     30.217804
# min                      286.295000                    189.928000
# 25%                      298.068000                    262.541000
# 50%                      299.887120                    299.477000
# 75%                      301.791137                    303.061000
# max                      310.270000                    370.910000
#
#        Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# count                 737453.000000              737453.000000
# mean                     290.754856                 520.244823
# std                       28.670105                 131.014924
# min                      185.962000                 149.218000
# 25%                      256.302000                 416.978000
# 50%                      299.011000                 491.878000
# 75%                      301.904000                 594.114000
# max                      371.593000                 862.274000
#
#        Flotation Column 02 Level  Flotation Column 03 Level  \
# count              737453.000000              737453.000000
# mean                  522.649555                 531.352662
# std                   128.165050                 150.842164
# min                   210.752000                 126.255000
# 25%                   441.883000                 411.325000
# 50%                   495.956000                 494.318000
# 75%                   595.464000                 601.249000
# max                   828.919000                 886.822000
#
#        Flotation Column 04 Level  Flotation Column 05 Level  \
# count              737453.000000              737453.000000
# mean                  420.320973                 425.251706
# std                    91.794432                  84.535822
# min                   162.201000                 166.991000
# 25%                   356.679000                 357.653000
# 50%                   411.974000                 408.773000
# 75%                   485.549000                 484.329000
# max                   680.359000                 675.644000
#
#        Flotation Column 06 Level  Flotation Column 07 Level  \
# count              737453.000000              737453.000000
# mean                  429.941018                 421.021231
# std                    89.862225                  84.891491
# min                   155.841000                 175.349000
# 25%                   358.497000                 356.772000
# 50%                   424.664575                 411.065000
# 75%                   492.684000                 476.465000
# max                   698.861000                 659.902000
#
#        % Iron Concentrate  % Silica Concentrate
# count       737453.000000         737453.000000
# mean            65.050068              2.326763
# std              1.118645              1.125554
# min             62.050000              0.600000
# 25%             64.370000              1.440000
# 50%             65.210000              2.000000
# 75%             65.860000              3.010000
# max             68.010000              5.530000

# %% [markdown]
# ## 3. Handle Missing Values and Indices

# %%
print("========= Missisng Values =========")
with pd.option_context('display.max_columns', None):
    display(df_mining.isna().sum().to_frame().T)

print("========= Index Counts =========")
idx_counts = df_mining.index.value_counts().sort_index()
display(idx_counts.to_frame().T)

print("========= Missing Indices (≠ 180) =========")
missing = idx_counts[idx_counts != 180]
display(missing.to_frame().T)

for time_stamp, count in missing.items():
    num_pads = 180 - count
    padding = df_mining.loc[time_stamp].tail(1)
    padding = pd.concat([padding] * num_pads)
    df_mining = pd.concat([df_mining, padding]).sort_index()

if len(df_mining.index.value_counts().loc[lambda x: x != 180]) == 0:
    print('\n✅ Missing rows have been handled correctly. New df_mining.shape:', df_mining.shape)
else:
    print('\n⚠️ Error: Dataset still has missing rows. df_mining.shape:', df_mining.shape)
# Out:
# ========= Missisng Values =========
#    % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  Ore Pulp Flow  \
# 0            0              0            0           0              0
#
#    Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0            0                 0                             0
#
#    Flotation Column 02 Air Flow  Flotation Column 03 Air Flow  \
# 0                             0                             0
#
#    Flotation Column 04 Air Flow  Flotation Column 05 Air Flow  \
# 0                             0                             0
#
#    Flotation Column 06 Air Flow  Flotation Column 07 Air Flow  \
# 0                             0                             0
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                          0                          0
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                          0                          0
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                          0                          0
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                          0                   0                     0
# ========= Index Counts =========
# date   2017-03-10 01:00:00  2017-03-10 02:00:00  2017-03-10 03:00:00  \
# count                  174                  180                  180
#
# date   2017-03-10 04:00:00  2017-03-10 05:00:00  2017-03-10 06:00:00  \
# count                  180                  180                  180
#
# date   2017-03-10 07:00:00  2017-03-10 08:00:00  2017-03-10 09:00:00  \
# count                  180                  180                  180
#
# date   2017-03-10 10:00:00  ...  2017-09-09 14:00:00  2017-09-09 15:00:00  \
# count                  180  ...                  180                  180
#
# date   2017-09-09 16:00:00  2017-09-09 17:00:00  2017-09-09 18:00:00  \
# count                  180                  180                  180
#
# date   2017-09-09 19:00:00  2017-09-09 20:00:00  2017-09-09 21:00:00  \
# count                  180                  180                  180
#
# date   2017-09-09 22:00:00  2017-09-09 23:00:00
# count                  180                  180
#
# [1 rows x 4097 columns]
# ========= Missing Indices (≠ 180) =========
# date   2017-03-10 01:00:00  2017-04-10 00:00:00
# count                  174                  179
# ✅ Missing rows have been handled correctly. New df_mining.shape: (737460, 23)

# %% [markdown]
# ## 4. Distribution of Target Column (% Silica Concentrate)

# %%
plt.figure(figsize=(8,6))
sns.histplot(df_mining['% Silica Concentrate'], bins=50, kde=True)
plt.title('Distribution of % Silica Concentrate')
plt.xlabel('% Silica Concentrate')
plt.show()

# %%
# Select only numeric columns (ignores timestamp + categorical)
num_cols = df_mining.select_dtypes(include=[np.number]).columns

# Layout (adjust as needed)
n_cols = 4
n_rows = int(np.ceil(len(num_cols) / n_cols))

plt.figure(figsize=(20, 4 * n_rows))

for i, col in enumerate(num_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    # sns.histplot(df_mining[col], bins=50, kde=True)
    plt.hist(df_mining[col], bins=50, alpha=0.7)
    plt.title(col, fontsize=10)
    plt.tight_layout()

plt.show()

# %% [markdown]
# ## 5. Time Trends for Target Column (% Silica Concentrate)

# %%
# Apply Rolling Statistics
rolling_window = 3*60*24 # one day rolling window
silica_rolling_mean = df_mining['% Silica Concentrate'].rolling(window=rolling_window, center=True).mean()
silica_rolling_std = df_mining['% Silica Concentrate'].rolling(window=rolling_window, center=True).std()

# Plot time trend
plt.figure(figsize=(22,4))
plt.plot(silica_rolling_mean.index, silica_rolling_mean, label='24-Hour Rolling Mean of % Silica')
plt.fill_between(silica_rolling_std.index, silica_rolling_mean - silica_rolling_std, silica_rolling_mean + silica_rolling_std, alpha=0.2, label='24-Hour Rolling Std of % Silica')
plt.title('% Silica Concentrate Over Time')
plt.xlabel('Time')
plt.ylabel('% Silica')
plt.legend()
plt.show()

# %%
# Apply Rolling Statistics
rolling_window = 3*60*24 # one day rolling window
# Note: Ensure the rolling function is applied to the data, 
# and the index is reflective of the data's true timestamps.
silica_rolling_mean = df_mining['% Silica Concentrate'].rolling(window=rolling_window, center=True).mean()
silica_rolling_std = df_mining['% Silica Concentrate'].rolling(window=rolling_window, center=True).std()

# --- MINIMAL CHANGES TO SOLVE THE GAP ISSUE ---

# 1. Drop NaN values from the rolling stats (this breaks the line across gaps)
silica_rolling_mean = silica_rolling_mean.dropna()
silica_rolling_std = silica_rolling_std.dropna()

plt.figure(figsize=(22,4))

# 2. Plot the cleaned data
# Plot Rolling Mean
plt.plot(silica_rolling_mean.index, silica_rolling_mean, label='24-Hour Rolling Mean of % Silica')

# # Plot Fill Between (Needs to align with the dropped NaNs)
# plt.fill_between(
#     silica_rolling_std.index,
#     silica_rolling_mean - silica_rolling_std,
#     silica_rolling_mean + silica_rolling_std, 
#     alpha=0.2, 
#     label='24-Hour Rolling Std of % Silica'
# )

plt.title('% Silica Concentrate Over Time')
plt.xlabel('Time')
plt.ylabel('% Silica')
plt.legend()
plt.show()

# %% [markdown]
# ## 6. Correlation Heatmap

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df_mining.corr(), annot=True, linewidths=0.003)
plt.title('Correlation Heatmap of Process Variables')
plt.show()

# %% [markdown]
# ## 7. Top Correlated Variables with Target Column (% Silica Concentrate)

# %%
# Find Top Correlations
top_corrs = df_mining.corr()['% Silica Concentrate'].abs().sort_values(ascending=False)[1:4]
print("Top correlated variables with % Silica Concentrate:")
print(top_corrs)

# Visualize Top Correlations
for col in top_corrs.index:
    sns.scatterplot(data=df_mining, x=col, y='% Silica Concentrate', alpha=0.1, s=5)
    plt.title(f'{col} vs. % Silica Concentrate')
    plt.show()
# Out:
# Top correlated variables with % Silica Concentrate:
# % Iron Concentrate              0.800561
# Flotation Column 01 Air Flow    0.219148
# Flotation Column 03 Air Flow    0.218879
# Name: % Silica Concentrate, dtype: float64

# %% [markdown]
# ## 8. Preliminary EDA Insights

# %% [markdown]
# - Dataset contains 737453 samples and 23 features covering a time range from 2017-03-10 01:00:00 to 2017-09-09 23:00:00.
# - After handling missing rows, each hourly block now contains 180 uniform samples (20-second frequency).
# - Sensor data collection was mostly consistent but samples are missing for half of 2017-03.
# - % Silica Concentrate (target) roughly ranges from 1% to 5%, with skew toward lower values.
# - Strong correlations (inverse proportionality) found between target and % Iron Concentrate.
# - Flotation Column 01 Air Flow and Flotation Column 03 Air Flow show moderate correlation with % Silica Concentrate.
